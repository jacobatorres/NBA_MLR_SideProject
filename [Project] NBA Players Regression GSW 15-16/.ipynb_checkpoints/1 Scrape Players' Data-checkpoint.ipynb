# %% [markdown]
# # Note: Install chromedriver at the same file as this one.

# %% [markdown]
# ### Functions

# %%
from bs4 import BeautifulSoup
import requests
from HTMLParser import HTMLParser
from time import sleep
import random
import csv
import hashlib
import requests
import re

import numpy as np
import pandas as pd

# In[50]:

class MLStripper(HTMLParser):
    def __init__(self):
        self.reset()
        self.strict = False
        self.convert_charrefs= True
        self.fed = []
    def handle_data(self, d):
        self.fed.append(d)
    def get_data(self):
        return ''.join(self.fed)

def strip_tags(html):
    s = MLStripper()
    s.feed(html)
    return s.get_data()


# In[58]:
from selenium import webdriver
import urllib2
import MySQLdb

# %% [markdown]
# ## get all the URLs for scraping!
# ## url composition: "http://www.nba.com/games/" + date of game from wiki + "//" + team A AT team B  + "//" + "/gameinfo.html"

# %%
#get url 
wiki_url = "https://en.wikipedia.org/wiki/2015–17_Golden_State_Warriors_season"
url = wiki_url

#use beautiful soup to parse more conveniently
r1 = urllib2.urlopen(url)
soup = BeautifulSoup(r1, 'html.parser')

wiki_table = soup.findAll('table', {'class':'toccolours'})

#get the relevant tables; i.e. the regular season sched and playoffs sched. We need these tables to generate the links
reg_season_sched = wiki_table[1]
playoffs_sched = wiki_table[2]

# %%
#regular season table
#get the date and the team acronyms for visiting the NBA play-by-play score
games_log = str(reg_season_sched).split('<tr style="background')
games_log = games_log[1:]

dates_teams = []
dates_teams_2 = []
for i in games_log:
    temp = i.split("https://watch.nba.com/game/")
    date_player = temp[1].split('"')
    dates_teams.append(date_player[0])

# %%
#playoffs season table

#comment this entire cell if you don't want playoff values
#get the date and the team acronyms for visiting the NBA play-by-play score
games_log = str(playoffs_sched).split('<tr style="background')

games_log = games_log[1:]

for i in games_log:
    temp = i.split("https://watch.nba.com/game/")
    date_player = temp[1].split('"')
    dates_teams_2.append(date_player[0])

# %%
#concatenate links from both regular season and playoffs
dates_teams = dates_teams + dates_teams_2
print(len(dates_teams))
# Out:
# 89

# %%
dates_teams
# Out:
# ['20161001/GSWTOR#',
#  '20161004/LACGSW#',
#  '20161006/SACGSW#',
#  '20161014/GSWDEN#',
#  '20161015/GSWLAL#',
#  '20161019/GSWLAL#',
#  '20161021/PORGSW#',
#  '20161025/SASGSW',
#  '20161028/GSWNOP',
#  '20161030/GSWPHX',
#  '20161101/GSWPOR',
#  '20161103/OKCGSW',
#  '20161104/GSWLAL',
#  '20161107/NOPGSW',
#  '20161109/DALGSW',
#  '20161110/GSWDEN',
#  '20161113/PHXGSW',
#  '20161116/GSWTOR',
#  '20161118/GSWBOS',
#  '20161119/GSWMIL',
#  '20161121/GSWIND',
#  '20161123/LALGSW',
#  '20161125/GSWLAL',
#  '20161126/MINGSW',
#  '20161128/ATLGSW',
#  '20161201/HOUGSW',
#  '20161203/PHXGSW',
#  '20161205/INDGSW',
#  '20161207/GSWLAC',
#  '20161208/GSWUTA',
#  '20161210/GSWMEM',
#  '20161211/GSWMIN',
#  '20161213/GSWNOP',
#  '20161215/NYKGSW',
#  '20161217/PORGSW',
#  '20161220/UTAGSW',
#  '20161222/GSWBKN',
#  '20161223/GSWDET',
#  '20161225/GSWCLE',
#  '20161228/TORGSW',
#  '20161230/DALGSW',
#  '20170102/DENGSW',
#  '20170104/PORGSW',
#  '20170106/MEMGSW',
#  '20170108/GSWSAC',
#  '20170110/MIAGSW',
#  '20170112/DETGSW',
#  '20170116/CLEGSW',
#  '20170118/OKCGSW',
#  '20170120/GSWHOU',
#  '20170122/GSWORL',
#  '20170123/GSWMIA',
#  '20170125/GSWCHA',
#  '20170128/LACGSW',
#  '20170129/GSWPOR',
#  '20170201/CHAGSW',
#  '20170202/GSWLAC',
#  '20170204/GSWSAC',
#  '20170208/CHIGSW',
#  '20170210/GSWMEM',
#  '20170211/GSWOKC',
#  '20170213/GSWDEN',
#  '20170215/SACGSW',
#  '20170223/LACGSW',
#  '20170225/BKNGSW',
#  '20170227/GSWPHI',
#  '20170228/GSWWAS',
#  '20170302/GSWCHI',
#  '20170305/GSWNYK',
#  '20170306/GSWATL',
#  '20170308/BOSGSW',
#  '20170310/GSWMIN',
#  '20170311/GSWSAS',
#  '20170314/PHIGSW',
#  '20170316/ORLGSW',
#  '20170318/MILGSW',
#  '20170320/GSWOKC',
#  '20170321/GSWDAL',
#  '20170324/SACGSW',
#  '20170326/MEMGSW',
#  '20170328/GSWHOU',
#  '20170329/GSWSAS',
#  '20170331/HOUGSW',
#  '20170402/WASGSW',
#  '20170404/MINGSW',
#  '20170405/GSWPHX',
#  '20170408/NOPGSW',
#  '20170410/UTAGSW',
#  '20170412/LALGSW']

# %% [markdown]
# ### Code below gets the data of the NBA player, his team and his position.
#
# ### End output is the NBA_teamnamefullnameposition.csv file

# %%
#get all the teams, put it in teams variable

teams = ['GSW']
for item in dates_teams:
    opp = item.split("/")[1][3:]
    
    
    if opp not in teams:
        teams.append(opp)

print(teams)
print(len(teams))
# Out:
# ['GSW', 'HOU', 'NOP', 'SAC', 'MEM', 'MIN', 'LAC', 'DEN', 'PHX', 'UTA', 'CHA', 'TOR', 'BKN', 'IND', 'BOS', 'MIL', 'DAL', 'LAL', 'POR', 'DET', 'CLE', 'CHI', 'PHI', 'NYK', 'WAS', 'ATL', 'MIA', 'ORL', 'OKC', 'SAS']
# 30

# %%
# once you get the teams, visit each team at: https://www.basketball-reference.com/teams/<team>/2016.html
# note the [PHO, BRK CHO] is there because the enconding is different in the basketball-reference website
nba_dicts = {}

for team in teams:
    
    try:
        browser = webdriver.Chrome(executable_path="C:\\Users\\jacob\\Downloads\\chromedriver.exe") #replace with .Firefox(), or with the browser of your choice

        url2 = "https://www.basketball-reference.com/teams/" + team + "/2016.html"

        browser.get(url2) #navigate to the page
        browser.find_element_by_xpath('//*[@id="roster"]') #returns the inner HTML as a string
        roster_text = browser.execute_script("return document.body.innerHTML")
        browser.close()

        text = roster_text.split("<h2>Roster</h2>")

        rlvt_text = text[1].split("</tbody>")
        rlvt_text2 = rlvt_text[0].split("<tbody>")[1]
        rlvt_text3 = rlvt_text2.split(r'<tr data-row="')[1:]

        name_list = []
        pos_list = []
        fn_list = []
        ln_list = []


        for i in range(0,len(rlvt_text3)):
            sample = strip_tags(rlvt_text3[i])
            name_pos = re.findall(r'(\d{1,2})([\Da-z]+\s[\Da-z]+)([A-Z]{0,2})(\d-\d+)([A-Z][a-z]+\s\d{1,2},\s\d{4})', sample)

            tempvar = re.split(r'([A-Z]+)', name_pos[0][1])
            name = "".join(tempvar[:len(tempvar)-2])
            pos = tempvar[-2]
            
            templist = name.strip(" ").split(" ")
            first_name = templist.pop(0)
            last_name = " ".join(templist)
            
            #print first_name, last_name

            name_list.append(name.strip(" "))
            pos_list.append(pos.strip(" "))
            fn_list.append(first_name)
            ln_list.append(last_name)


            #print name, pos, team
            
        name_series = pd.Series(name_list)
        pos_series = pd.Series(pos_list)
        fn_series = pd.Series(fn_list)
        ln_series = pd.Series(ln_list)
        
        team_series = pd.Series([team for asd in range(0, len(name_series))])

        sample_dict = {'names': name_series, 'first_name':fn_series, 'last_name': ln_series, 'pos': pos_series, 'team':team_series}

        team_dict = pd.DataFrame(sample_dict)

        nba_dicts[team] = team_dict
        print team 
    except Exception as e:
        print "Error on ", url2
# Out:
# GSW
# HOU
# NOP
# SAC
# MEM
# MIN
# LAC
# DEN
# Error on  https://www.basketball-reference.com/teams/PHX/2016.html
# UTA
# Error on  https://www.basketball-reference.com/teams/CHA/2016.html
# TOR
# Error on  https://www.basketball-reference.com/teams/BKN/2016.html
# IND
# BOS
# MIL
# DAL
# LAL
# POR
# DET
# CLE
# CHI
# PHI
# NYK
# WAS
# ATL
# MIA
# ORL
# OKC
# SAS

# %%
#oops, turns out we still need to parse Phoenix, Brooklyn and Charlotte 
#since in basketball-references.com they are encoded differently

for team in ["PHO", "BRK", "CHO"]:
    
    try:
        browser = webdriver.Chrome(executable_path="C:\\Users\\jacob\\Downloads\\chromedriver.exe") #replace with .Firefox(), or with the browser of your choice

        url2 = "https://www.basketball-reference.com/teams/" + team + "/2016.html"

        browser.get(url2) #navigate to the page
        browser.find_element_by_xpath('//*[@id="roster"]') #returns the inner HTML as a string
        roster_text = browser.execute_script("return document.body.innerHTML")
        browser.close()

        text = roster_text.split("<h2>Roster</h2>")

        rlvt_text = text[1].split("</tbody>")
        rlvt_text2 = rlvt_text[0].split("<tbody>")[1]
        rlvt_text3 = rlvt_text2.split(r'<tr data-row="')[1:]

        name_list = []
        pos_list = []
        fn_list = []
        ln_list = []


        for i in range(0,len(rlvt_text3)):
            sample = strip_tags(rlvt_text3[i])
            name_pos = re.findall(r'(\d{1,2})([\Da-z]+\s[\Da-z]+)([A-Z]{0,2})(\d-\d+)([A-Z][a-z]+\s\d{1,2},\s\d{4})', sample)

            tempvar = re.split(r'([A-Z]+)', name_pos[0][1])
            name = "".join(tempvar[:len(tempvar)-2])
            pos = tempvar[-2]
            
            templist = name.strip(" ").split(" ")
            first_name = templist.pop(0)
            last_name = " ".join(templist)

            name_list.append(name.strip(" "))
            pos_list.append(pos.strip(" "))
            fn_list.append(first_name)
            ln_list.append(last_name)



        name_series = pd.Series(name_list)
        pos_series = pd.Series(pos_list)
        fn_series = pd.Series(fn_list)
        ln_series = pd.Series(ln_list)
        
        team_series = pd.Series([team for asd in range(0, len(name_series))])

        sample_dict = {'names': name_series, 'first_name':fn_series, 'last_name': ln_series, 'pos': pos_series, 'team':team_series}

        team_dict = pd.DataFrame(sample_dict)

        nba_dicts[team] = team_dict
        print(team)
    except:
        print "wow"
# Out:
# PHO
# BRK
# CHO

# %%
# verify that all 30 teams are in dict
print(nba_dicts.keys(), len(nba_dicts.keys()))

#concatenate all values into one big data frame
NBA_TNAMEPOS_DF = pd.concat(nba_dicts.values(), ignore_index=True)
# Out:
# (['MIL', 'GSW', 'MIN', 'TOR', 'ATL', 'BOS', 'DET', 'NYK', 'DEN', 'SAC', 'POR', 'OKC', 'MIA', 'CLE', 'SAS', 'UTA', 'CHI', 'CHO', 'HOU', 'WAS', 'LAL', 'PHI', 'PHO', 'MEM', 'LAC', 'DAL', 'ORL', 'BRK', 'IND', 'NOP'], 30)

# %%
#save to csv
NBA_TNAMEPOS_DF.to_csv("NBA_teamnamepos_data.csv", sep=',')

# %%
#save to mysql

#connect to the MySQL database
conn = MySQLdb.connect(host = "localhost",
                      user="root",
                      passwd="SQL092219951996",
                     db="nba_database")

x = conn.cursor()

for i in range(0, len(NBA_TNAMEPOS_DF)):
    
    fn = NBA_TNAMEPOS_DF.iloc[i][0]
    ln = NBA_TNAMEPOS_DF.iloc[i][1]
    n = NBA_TNAMEPOS_DF.iloc[i][2]
    p = NBA_TNAMEPOS_DF.iloc[i][3]
    t = NBA_TNAMEPOS_DF.iloc[i][4]
    
    try:
        x.execute("""INSERT INTO player_team value (NULL, %s,%s, %s, %s, %s)""", tuple([fn,ln,n,p,t]))
        conn.commit()
        print i, tuple([fn,ln,n,p,t])
    except Exception as e:
        print "AH!!!!", e
        conn.rollback()
    



conn.close()
# Out:
# 0 (u'Giannis', u'Antetokounmpo', u'Giannis Antetokounmpo', u'PG', 'MIL')
# 1 (u'Jerryd', u'Bayless', u'Jerryd Bayless', u'SG', 'MIL')
# 2 (u'Michael', u'Carter-Williams', u'Michael Carter-Williams', u'PG', 'MIL')
# 3 (u'Chris', u'Copeland', u'Chris Copeland', u'PF', 'MIL')
# 4 (u'Jared', u'Cunningham', u'Jared Cunningham', u'SG', 'MIL')
# 5 (u'Tyler', u'Ennis', u'Tyler Ennis', u'PG', 'MIL')
# 6 (u'John', u'Henson', u'John Henson', u'C', 'MIL')
# 7 (u'Damien', u'Inglis', u'Damien Inglis', u'SF', 'MIL')
# 8 (u'O.J.', u'Mayo', u'O.J. Mayo', u'SG', 'MIL')
# 9 (u'Khris', u'Middleton', u'Khris Middleton', u'SG', 'MIL')
# 10 (u'Greg', u'Monroe', u'Greg Monroe', u'C', 'MIL')
# 11 (u'Steve', u'Novak', u'Steve Novak', u'PF', 'MIL')
# 12 (u'Johnny', u"O'Bryant", u"Johnny O'Bryant", u'PF', 'MIL')
# 13 (u'Jabari', u'Parker', u'Jabari Parker', u'PF', 'MIL')
# 14 (u'Miles', u'Plumlee', u'Miles Plumlee', u'C', 'MIL')
# 15 (u'Greivis', u'Vasquez', u'Greivis Vasquez', u'PG', 'MIL')
# 16 (u'Rashad', u'Vaughn', u'Rashad Vaughn', u'SG', 'MIL')
# 17 (u'Leandro', u'Barbosa', u'Leandro Barbosa', u'SG', 'GSW')
# 18 (u'Harrison', u'Barnes', u'Harrison Barnes', u'SF', 'GSW')
# 19 (u'Andrew', u'Bogut', u'Andrew Bogut', u'C', 'GSW')
# 20 (u'Ian', u'Clark', u'Ian Clark', u'SG', 'GSW')
# 21 (u'Stephen', u'Curry', u'Stephen Curry', u'PG', 'GSW')
# 22 (u'Festus', u'Ezeli', u'Festus Ezeli', u'C', 'GSW')
# 23 (u'Draymond', u'Green', u'Draymond Green', u'PF', 'GSW')
# 24 (u'Andre', u'Iguodala', u'Andre Iguodala', u'SF', 'GSW')
# 25 (u'Shaun', u'Livingston', u'Shaun Livingston', u'PG', 'GSW')
# 26 (u'Kevon', u'Looney', u'Kevon Looney', u'PF', 'GSW')
# 27 (u'James', u'Michael McAdoo', u'James Michael McAdoo', u'PF', 'GSW')
# 28 (u'Brandon', u'Rush', u'Brandon Rush', u'SG', 'GSW')
# 29 (u'Marreese', u'Speights', u'Marreese Speights', u'C', 'GSW')
# 30 (u'Jason', u'Thompson', u'Jason Thompson', u'C', 'GSW')
# 31 (u'Klay', u'Thompson', u'Klay Thompson', u'SG', 'GSW')
# 32 (u'Anderson', u'Varejao', u'Anderson Varejao', u'C', 'GSW')
# 33 (u'Nemanja', u'Bjelica', u'Nemanja Bjelica', u'PF', 'MIN')
# 34 (u'Gorgui', u'Dieng', u'Gorgui Dieng', u'C', 'MIN')
# 35 (u'Kevin', u'Garnett', u'Kevin Garnett', u'PF', 'MIN')
# 36 (u'Tyus', u'Jones', u'Tyus Jones', u'PG', 'MIN')
# 37 (u'Zach', u'LaVine', u'Zach LaVine', u'SG', 'MIN')
# 38 (u'Kevin', u'Martin', u'Kevin Martin', u'SG', 'MIN')
# 39 (u'Andre', u'Miller', u'Andre Miller', u'PG', 'MIN')
# 40 (u'Shabazz', u'Muhammad', u'Shabazz Muhammad', u'SF', 'MIN')
# 41 (u'Adreian', u'Payne', u'Adreian Payne', u'PF', 'MIN')
# 42 (u'Nikola', u'Pekovic', u'Nikola Pekovic', u'C', 'MIN')
# 43 (u'Tayshaun', u'Prince', u'Tayshaun Prince', u'SF', 'MIN')
# 44 (u'Ricky', u'Rubio', u'Ricky Rubio', u'PG', 'MIN')
# 45 (u'Damjan', u'Rudez', u'Damjan Rudez', u'SF', 'MIN')
# 46 (u'Greg', u'Smith', u'Greg Smith', u'PF', 'MIN')
# 47 (u'Karl-Anthony', u'Towns', u'Karl-Anthony Towns', u'C', 'MIN')
# 48 (u'Andrew', u'Wiggins', u'Andrew Wiggins', u'SF', 'MIN')
# 49 (u'Anthony', u'Bennett', u'Anthony Bennett', u'PF', 'TOR')
# 50 (u'Bismack', u'Biyombo', u'Bismack Biyombo', u'C', 'TOR')
# 51 (u'Bruno', u'Caboclo', u'Bruno Caboclo', u'SF', 'TOR')
# 52 (u'DeMarre', u'Carroll', u'DeMarre Carroll', u'SF', 'TOR')
# 53 (u'DeMar', u'DeRozan', u'DeMar DeRozan', u'SG', 'TOR')
# 54 (u'James', u'Johnson', u'James Johnson', u'PF', 'TOR')
# 55 (u'Cory', u'Joseph', u'Cory Joseph', u'SG', 'TOR')
# 56 (u'Kyle', u'Lowry', u'Kyle Lowry', u'PG', 'TOR')
# 57 (u'Lucas', u'Nogueira', u'Lucas Nogueira', u'C', 'TOR')
# 58 (u'Patrick', u'Patterson', u'Patrick Patterson', u'PF', 'TOR')
# 59 (u'Norman', u'Powell', u'Norman Powell', u'SG', 'TOR')
# 60 (u'Terrence', u'Ross', u'Terrence Ross', u'SF', 'TOR')
# 61 (u'Luis', u'Scola', u'Luis Scola', u'PF', 'TOR')
# 62 (u'Jason', u'Thompson', u'Jason Thompson', u'C', 'TOR')
# 63 (u'Jonas', u'Valanciunas', u'Jonas Valanciunas', u'C', 'TOR')
# 64 (u'Delon', u'Wright', u'Delon Wright', u'PG', 'TOR')
# 65 (u'Kent', u'Bazemore', u'Kent Bazemore', u'SF', 'ATL')
# 66 (u'Tim', u'Hardaway', u'Tim Hardaway', u'SG', 'ATL')
# 67 (u'Kirk', u'Hinrich', u'Kirk Hinrich', u'PG', 'ATL')
# 68 (u'Justin', u'Holiday', u'Justin Holiday', u'SG', 'ATL')
# 69 (u'Al', u'Horford', u'Al Horford', u'C', 'ATL')
# 70 (u'Kris', u'Humphries', u'Kris Humphries', u'PF', 'ATL')
# 71 (u'Kyle', u'Korver', u'Kyle Korver', u'SG', 'ATL')
# 72 (u'Shelvin', u'Mack', u'Shelvin Mack', u'PG', 'ATL')
# 73 (u'Paul', u'Millsap', u'Paul Millsap', u'PF', 'ATL')
# 74 (u'Mike', u'Muscala', u'Mike Muscala', u'C', 'ATL')
# 75 (u'Lamar', u'Patterson', u'Lamar Patterson', u'SG', 'ATL')
# 76 (u'Dennis', u'Schroder', u'Dennis Schroder', u'PG', 'ATL')
# 77 (u'Mike', u'Scott', u'Mike Scott', u'PF', 'ATL')
# 78 (u'Thabo', u'Sefolosha', u'Thabo Sefolosha', u'SF', 'ATL')
# 79 (u'Tiago', u'Splitter', u'Tiago Splitter', u'C', 'ATL')
# 80 (u'Edy', u'Tavares', u'Edy Tavares', u'C', 'ATL')
# 81 (u'Jeff', u'Teague', u'Jeff Teague', u'PG', 'ATL')
# 82 (u'Avery', u'Bradley', u'Avery Bradley', u'SG', 'BOS')
# 83 (u'Coty', u'Clarke', u'Coty Clarke', u'SF', 'BOS')
# 84 (u'Jae', u'Crowder', u'Jae Crowder', u'SF', 'BOS')
# 85 (u'R.J.', u'Hunter', u'R.J. Hunter', u'SG', 'BOS')
# 86 (u'Jonas', u'Jerebko', u'Jonas Jerebko', u'PF', 'BOS')
# 87 (u'Amir', u'Johnson', u'Amir Johnson', u'PF', 'BOS')
# 88 (u'David', u'Lee', u'David Lee', u'PF', 'BOS')
# 89 (u'Jordan', u'Mickey', u'Jordan Mickey', u'PF', 'BOS')
# 90 (u'Kelly', u'Olynyk', u'Kelly Olynyk', u'C', 'BOS')
# 91 (u'Terry', u'Rozier', u'Terry Rozier', u'PG', 'BOS')
# 92 (u'Marcus', u'Smart', u'Marcus Smart', u'PG', 'BOS')
# 93 (u'Jared', u'Sullinger', u'Jared Sullinger', u'PF', 'BOS')
# 94 (u'Isaiah', u'Thomas', u'Isaiah Thomas', u'PG', 'BOS')
# 95 (u'Evan', u'Turner', u'Evan Turner', u'SG', 'BOS')
# 96 (u'James', u'Young', u'James Young', u'SG', 'BOS')
# 97 (u'Tyler', u'Zeller', u'Tyler Zeller', u'C', 'BOS')
# 98 (u'Joel', u'Anthony', u'Joel Anthony', u'C', 'DET')
# 99 (u'Aron', u'Baynes', u'Aron Baynes', u'C', 'DET')
# 100 (u'Steve', u'Blake', u'Steve Blake', u'PG', 'DET')
# 101 (u'Reggie', u'Bullock', u'Reggie Bullock', u'SF', 'DET')
# 102 (u'Kentavious', u'Caldwell-Pope', u'Kentavious Caldwell-Pope', u'SG', 'DET')
# 103 (u'Spencer', u'Dinwiddie', u'Spencer Dinwiddie', u'PG', 'DET')
# 104 (u'Andre', u'Drummond', u'Andre Drummond', u'C', 'DET')
# 105 (u'Justin', u'Harper', u'Justin Harper', u'PF', 'DET')
# 106 (u'Tobias', u'Harris', u'Tobias Harris', u'PF', 'DET')
# 107 (u'Darrun', u'Hilliard', u'Darrun Hilliard', u'SG', 'DET')
# 108 (u'Ersan', u'Ilyasova', u'Ersan Ilyasova', u'PF', 'DET')
# 109 (u'Reggie', u'Jackson', u'Reggie Jackson', u'PG', 'DET')
# 110 (u'Brandon', u'Jennings', u'Brandon Jennings', u'PG', 'DET')
# 111 (u'Stanley', u'Johnson', u'Stanley Johnson', u'SF', 'DET')
# 112 (u'Jodie', u'Meeks', u'Jodie Meeks', u'SG', 'DET')
# 113 (u'Marcus', u'Morris', u'Marcus Morris', u'SF', 'DET')
# 114 (u'Anthony', u'Tolliver', u'Anthony Tolliver', u'PF', 'DET')
# 115 (u'Arron', u'Afflalo', u'Arron Afflalo', u'SG', 'NYK')
# 116 (u'Lou', u'Amundson', u'Lou Amundson', u'PF', 'NYK')
# 117 (u'Thanasis', u'Antetokounmpo', u'Thanasis Antetokounmpo', u'SF', 'NYK')
# 118 (u'Carmelo', u'Anthony', u'Carmelo Anthony', u'SF', 'NYK')
# 119 (u'Jose', u'Calderon', u'Jose Calderon', u'PG', 'NYK')
# 120 (u'Cleanthony', u'Early', u'Cleanthony Early', u'SF', 'NYK')
# 121 (u'Jimmer', u'Fredette', u'Jimmer Fredette', u'SG', 'NYK')
# 122 (u'Langston', u'Galloway', u'Langston Galloway', u'PG', 'NYK')
# 123 (u'Jerian', u'Grant', u'Jerian Grant', u'PG', 'NYK')
# 124 (u'Robin', u'Lopez', u'Robin Lopez', u'C', 'NYK')
# 125 (u'Kyle', u"O'Quinn", u"Kyle O'Quinn", u'PF', 'NYK')
# 126 (u'Kristaps', u'Porzingis', u'Kristaps Porzingis', u'PF', 'NYK')
# 127 (u'Kevin', u'Seraphin', u'Kevin Seraphin', u'C', 'NYK')
# 128 (u'Lance', u'Thomas', u'Lance Thomas', u'PF', 'NYK')
# 129 (u'Sasha', u'Vujacic', u'Sasha Vujacic', u'SG', 'NYK')
# 130 (u'Derrick', u'Williams', u'Derrick Williams', u'SF', 'NYK')
# 131 (u'Darrell', u'Arthur', u'Darrell Arthur', u'PF', 'DEN')
# 132 (u'D.J.', u'Augustin', u'D.J. Augustin', u'PG', 'DEN')
# 133 (u'Will', u'Barton', u'Will Barton', u'SG', 'DEN')
# 134 (u'Kenneth', u'Faried', u'Kenneth Faried', u'PF', 'DEN')
# 135 (u'Randy', u'Foye', u'Randy Foye', u'SG', 'DEN')
# 136 (u'Danilo', u'Gallinari', u'Danilo Gallinari', u'SF', 'DEN')
# 137 (u'Erick', u'Green', u'Erick Green', u'PG', 'DEN')
# 138 (u'Gary', u'Harris', u'Gary Harris', u'SG', 'DEN')
# 139 (u'J.J.', u'Hickson', u'J.J. Hickson', u'C', 'DEN')
# 140 (u'Nikola', u'Jokic', u'Nikola Jokic', u'C', 'DEN')
# 141 (u'Sean', u'Kilpatrick', u'Sean Kilpatrick', u'SG', 'DEN')
# 142 (u'Joffrey', u'Lauvergne', u'Joffrey Lauvergne', u'C', 'DEN')
# 143 (u'Mike', u'Miller', u'Mike Miller', u'SF', 'DEN')
# 144 (u'Emmanuel', u'Mudiay', u'Emmanuel Mudiay', u'PG', 'DEN')
# 145 (u'Jameer', u'Nelson', u'Jameer Nelson', u'PG', 'DEN')
# 146 (u'Jusuf', u'Nurkic', u'Jusuf Nurkic', u'C', 'DEN')
# 147 (u'Kostas', u'Papanikolaou', u'Kostas Papanikolaou', u'SF', 'DEN')
# 148 (u'JaKarr', u'Sampson', u'JaKarr Sampson', u'SF', 'DEN')
# 149 (u'Axel', u'Toupane', u'Axel Toupane', u'SF', 'DEN')
# 150 (u'Quincy', u'Acy', u'Quincy Acy', u'PF', 'SAC')
# 151 (u'James', u'Anderson', u'James Anderson', u'SG', 'SAC')
# 152 (u'Marco', u'Belinelli', u'Marco Belinelli', u'SG', 'SAC')
# 153 (u'Caron', u'Butler', u'Caron Butler', u'SF', 'SAC')
# 154 (u'Omri', u'Casspi', u'Omri Casspi', u'PF', 'SAC')
# 155 (u'Willie', u'Cauley-Stein', u'Willie Cauley-Stein', u'C', 'SAC')
# 156 (u'Darren', u'Collison', u'Darren Collison', u'PG', 'SAC')
# 157 (u'DeMarcus', u'Cousins', u'DeMarcus Cousins', u'C', 'SAC')
# 158 (u'Seth', u'Curry', u'Seth Curry', u'PG', 'SAC')
# 159 (u'Duje', u'Dukan', u'Duje Dukan', u'SF', 'SAC')
# 160 (u'Rudy', u'Gay', u'Rudy Gay', u'SF', 'SAC')
# 161 (u'Kosta', u'Koufos', u'Kosta Koufos', u'C', 'SAC')
# 162 (u'Ben', u'McLemore', u'Ben McLemore', u'SG', 'SAC')
# 163 (u'Eric', u'Moreland', u'Eric Moreland', u'PF', 'SAC')
# 164 (u'Rajon', u'Rondo', u'Rajon Rondo', u'PG', 'SAC')
# 165 (u'Cliff', u'Alexander', u'Cliff Alexander', u'PF', 'POR')
# 166 (u'Al-Farouq', u'Aminu', u'Al-Farouq Aminu', u'SF', 'POR')
# 167 (u'Pat', u'Connaughton', u'Pat Connaughton', u'SG', 'POR')
# 168 (u'Allen', u'Crabbe', u'Allen Crabbe', u'SG', 'POR')
# 169 (u'Ed', u'Davis', u'Ed Davis', u'PF', 'POR')
# 170 (u'Tim', u'Frazier', u'Tim Frazier', u'PG', 'POR')
# 171 (u'Maurice', u'Harkless', u'Maurice Harkless', u'SF', 'POR')
# 172 (u'Gerald', u'Henderson', u'Gerald Henderson', u'SG', 'POR')
# 173 (u'Chris', u'Kaman', u'Chris Kaman', u'C', 'POR')
# 174 (u'Meyers', u'Leonard', u'Meyers Leonard', u'PF', 'POR')
# 175 (u'Damian', u'Lillard', u'Damian Lillard', u'PG', 'POR')
# 176 (u'C.J.', u'McCollum', u'C.J. McCollum', u'SG', 'POR')
# 177 (u'Luis', u'Montero', u'Luis Montero', u'SG', 'POR')
# 178 (u'Mason', u'Plumlee', u'Mason Plumlee', u'C', 'POR')
# 179 (u'Brian', u'Roberts', u'Brian Roberts', u'PG', 'POR')
# 180 (u'Noah', u'Vonleh', u'Noah Vonleh', u'PF', 'POR')
# 181 (u'Steven', u'Adams', u'Steven Adams', u'C', 'OKC')
# 182 (u'D.J.', u'Augustin', u'D.J. Augustin', u'PG', 'OKC')
# 183 (u'Nick', u'Collison', u'Nick Collison', u'PF', 'OKC')
# 184 (u'Kevin', u'Durant', u'Kevin Durant', u'SF', 'OKC')
# 185 (u'Randy', u'Foye', u'Randy Foye', u'SG', 'OKC')
# 186 (u'Josh', u'Huestis', u'Josh Huestis', u'PF', 'OKC')
# 187 (u'Serge', u'Ibaka', u'Serge Ibaka', u'PF', 'OKC')
# 188 (u'Enes', u'Kanter', u'Enes Kanter', u'C', 'OKC')
# 189 (u'Mitch', u'McGary', u'Mitch McGary', u'PF', 'OKC')
# 190 (u'Nazr', u'Mohammed', u'Nazr Mohammed', u'C', 'OKC')
# 191 (u'Anthony', u'Morrow', u'Anthony Morrow', u'SG', 'OKC')
# 192 (u'Steve', u'Novak', u'Steve Novak', u'PF', 'OKC')
# 193 (u'Cameron', u'Payne', u'Cameron Payne', u'PG', 'OKC')
# 194 (u'Andre', u'Roberson', u'Andre Roberson', u'SG', 'OKC')
# 195 (u'Kyle', u'Singler', u'Kyle Singler', u'SF', 'OKC')
# 196 (u'Dion', u'Waiters', u'Dion Waiters', u'SG', 'OKC')
# 197 (u'Russell', u'Westbrook', u'Russell Westbrook', u'PG', 'OKC')
# 198 (u'Chris', u'Andersen', u'Chris Andersen', u'C', 'MIA')
# 199 (u'Chris', u'Bosh', u'Chris Bosh', u'PF', 'MIA')
# 200 (u'Mario', u'Chalmers', u'Mario Chalmers', u'PG', 'MIA')
# 201 (u'Luol', u'Deng', u'Luol Deng', u'PF', 'MIA')
# 202 (u'Goran', u'Dragic', u'Goran Dragic', u'PG', 'MIA')
# 203 (u'James', u'Ennis', u'James Ennis', u'SF', 'MIA')
# 204 (u'Gerald', u'Green', u'Gerald Green', u'SG', 'MIA')
# 205 (u'Udonis', u'Haslem', u'Udonis Haslem', u'PF', 'MIA')
# 206 (u'Joe', u'Johnson', u'Joe Johnson', u'SF', 'MIA')
# 207 (u'Tyler', u'Johnson', u'Tyler Johnson', u'SG', 'MIA')
# 208 (u'Josh', u'McRoberts', u'Josh McRoberts', u'PF', 'MIA')
# 209 (u'Josh', u'Richardson', u'Josh Richardson', u'SG', 'MIA')
# 210 (u'Jarnell', u'Stokes', u'Jarnell Stokes', u'C', 'MIA')
# 211 (u"Amar'e", u'Stoudemire', u"Amar'e Stoudemire", u'C', 'MIA')
# 212 (u'Beno', u'Udrih', u'Beno Udrih', u'PG', 'MIA')
# 213 (u'Dwyane', u'Wade', u'Dwyane Wade', u'SG', 'MIA')
# 214 (u'Briante', u'Weber', u'Briante Weber', u'PG', 'MIA')
# 215 (u'Hassan', u'Whiteside', u'Hassan Whiteside', u'C', 'MIA')
# 216 (u'Justise', u'Winslow', u'Justise Winslow', u'SF', 'MIA')
# 217 (u'Jared', u'Cunningham', u'Jared Cunningham', u'SG', 'CLE')
# 218 (u'Matthew', u'Dellavedova', u'Matthew Dellavedova', u'PG', 'CLE')
# 219 (u'Channing', u'Frye', u'Channing Frye', u'C', 'CLE')
# 220 (u'Joe', u'Harris', u'Joe Harris', u'SG', 'CLE')
# 221 (u'Kyrie', u'Irving', u'Kyrie Irving', u'PG', 'CLE')
# 222 (u'LeBron', u'James', u'LeBron James', u'SF', 'CLE')
# 223 (u'Richard', u'Jefferson', u'Richard Jefferson', u'SF', 'CLE')
# 224 (u'Dahntay', u'Jones', u'Dahntay Jones', u'SF', 'CLE')
# 225 (u'James', u'Jones', u'James Jones', u'SF', 'CLE')
# 226 (u'Sasha', u'Kaun', u'Sasha Kaun', u'C', 'CLE')
# 227 (u'Kevin', u'Love', u'Kevin Love', u'PF', 'CLE')
# 228 (u'Jordan', u'McRae', u'Jordan McRae', u'PG', 'CLE')
# 229 (u'Timofey', u'Mozgov', u'Timofey Mozgov', u'C', 'CLE')
# 230 (u'Iman', u'Shumpert', u'Iman Shumpert', u'SG', 'CLE')
# 231 (u'J.R.', u'Smith', u'J.R. Smith', u'SG', 'CLE')
# 232 (u'Tristan', u'Thompson', u'Tristan Thompson', u'PF', 'CLE')
# 233 (u'Anderson', u'Varejao', u'Anderson Varejao', u'C', 'CLE')
# 234 (u'Mo', u'Williams', u'Mo Williams', u'PG', 'CLE')
# 235 (u'LaMarcus', u'Aldridge', u'LaMarcus Aldridge', u'PF', 'SAS')
# 236 (u'Kyle', u'Anderson', u'Kyle Anderson', u'SF', 'SAS')
# 237 (u'Matt', u'Bonner', u'Matt Bonner', u'C', 'SAS')
# 238 (u'Rasual', u'Butler', u'Rasual Butler', u'SF', 'SAS')
# 239 (u'Boris', u'Diaw', u'Boris Diaw', u'PF', 'SAS')
# 240 (u'Tim', u'Duncan', u'Tim Duncan', u'C', 'SAS')
# 241 (u'Manu', u'Ginobili', u'Manu Ginobili', u'SG', 'SAS')
# 242 (u'Danny', u'Green', u'Danny Green', u'SG', 'SAS')
# 243 (u'Kawhi', u'Leonard', u'Kawhi Leonard', u'SF', 'SAS')
# 244 (u'Boban', u'Marjanovic', u'Boban Marjanovic', u'C', 'SAS')
# 245 (u'Kevin', u'Martin', u'Kevin Martin', u'SG', 'SAS')
# 246 (u'Ray', u'McCallum', u'Ray McCallum', u'PG', 'SAS')
# 247 (u'Andre', u'Miller', u'Andre Miller', u'PG', 'SAS')
# 248 (u'Patty', u'Mills', u'Patty Mills', u'PG', 'SAS')
# 249 (u'Tony', u'Parker', u'Tony Parker', u'PG', 'SAS')
# 250 (u'Jonathon', u'Simmons', u'Jonathon Simmons', u'SG', 'SAS')
# 251 (u'David', u'West', u'David West', u'PF', 'SAS')
# 252 (u'Trevor', u'Booker', u'Trevor Booker', u'PF', 'UTA')
# 253 (u'Trey', u'Burke', u'Trey Burke', u'PG', 'UTA')
# 254 (u'Alec', u'Burks', u'Alec Burks', u'SG', 'UTA')
# 255 (u'Derrick', u'Favors', u'Derrick Favors', u'PF', 'UTA')
# 256 (u'Rudy', u'Gobert', u'Rudy Gobert', u'C', 'UTA')
# 257 (u'Erick', u'Green', u'Erick Green', u'PG', 'UTA')
# 258 (u'Gordon', u'Hayward', u'Gordon Hayward', u'SF', 'UTA')
# 259 (u'Rodney', u'Hood', u'Rodney Hood', u'SG', 'UTA')
# 260 (u'Joe', u'Ingles', u'Joe Ingles', u'SF', 'UTA')
# 261 (u'Chris', u'Johnson', u'Chris Johnson', u'SF', 'UTA')
# 262 (u'Trey', u'Lyles', u'Trey Lyles', u'PF', 'UTA')
# 263 (u'Shelvin', u'Mack', u'Shelvin Mack', u'PG', 'UTA')
# 264 (u'Elijah', u'Millsap', u'Elijah Millsap', u'SG', 'UTA')
# 265 (u'Raul', u'Neto', u'Raul Neto', u'PG', 'UTA')
# 266 (u'J.J.', u"O'Brien", u"J.J. O'Brien", u'SF', 'UTA')
# 267 (u'Tibor', u'Pleiss', u'Tibor Pleiss', u'C', 'UTA')
# 268 (u'Jeff', u'Withey', u'Jeff Withey', u'C', 'UTA')
# 269 (u'Cameron', u'Bairstow', u'Cameron Bairstow', u'C', 'CHI')
# 270 (u'Aaron', u'Brooks', u'Aaron Brooks', u'PG', 'CHI')
# 271 (u'Jimmy', u'Butler', u'Jimmy Butler', u'SG', 'CHI')
# 272 (u'Mike', u'Dunleavy', u'Mike Dunleavy', u'SF', 'CHI')
# 273 (u'Cristiano', u'Felicio', u'Cristiano Felicio', u'C', 'CHI')
# 274 (u'Pau', u'Gasol', u'Pau Gasol', u'C', 'CHI')
# 275 (u'Taj', u'Gibson', u'Taj Gibson', u'PF', 'CHI')
# 276 (u'Kirk', u'Hinrich', u'Kirk Hinrich', u'PG', 'CHI')
# 277 (u'Justin', u'Holiday', u'Justin Holiday', u'SG', 'CHI')
# 278 (u'Doug', u'McDermott', u'Doug McDermott', u'SF', 'CHI')
# 279 (u'Nikola', u'Mirotic', u'Nikola Mirotic', u'PF', 'CHI')
# 280 (u"E'Twaun", u'Moore', u"E'Twaun Moore", u'SG', 'CHI')
# 281 (u'Joakim', u'Noah', u'Joakim Noah', u'C', 'CHI')
# 282 (u'Bobby', u'Portis', u'Bobby Portis', u'PF', 'CHI')
# 283 (u'Derrick', u'Rose', u'Derrick Rose', u'PG', 'CHI')
# 284 (u'Tony', u'Snell', u'Tony Snell', u'SF', 'CHI')
# 285 (u'Nicolas', u'Batum', u'Nicolas Batum', u'SF', 'CHO')
# 286 (u'Troy', u'Daniels', u'Troy Daniels', u'SG', 'CHO')
# 287 (u'Jorge', u'Gutierrez', u'Jorge Gutierrez', u'PG', 'CHO')
# 288 (u'P.J.', u'Hairston', u'P.J. Hairston', u'SF', 'CHO')
# 289 (u'Tyler', u'Hansbrough', u'Tyler Hansbrough', u'PF', 'CHO')
# 290 (u'Aaron', u'Harrison', u'Aaron Harrison', u'SG', 'CHO')
# 291 (u'Spencer', u'Hawes', u'Spencer Hawes', u'PF', 'CHO')
# 292 (u'Al', u'Jefferson', u'Al Jefferson', u'C', 'CHO')
# 293 (u'Frank', u'Kaminsky', u'Frank Kaminsky', u'C', 'CHO')
# 294 (u'Michael', u'Kidd-Gilchrist', u'Michael Kidd-Gilchrist', u'SF', 'CHO')
# 295 (u'Jeremy', u'Lamb', u'Jeremy Lamb', u'SG', 'CHO')
# 296 (u'Courtney', u'Lee', u'Courtney Lee', u'SG', 'CHO')
# 297 (u'Jeremy', u'Lin', u'Jeremy Lin', u'SG', 'CHO')
# 298 (u'Brian', u'Roberts', u'Brian Roberts', u'PG', 'CHO')
# 299 (u'Kemba', u'Walker', u'Kemba Walker', u'PG', 'CHO')
# 300 (u'Marvin', u'Williams', u'Marvin Williams', u'PF', 'CHO')
# 301 (u'Cody', u'Zeller', u'Cody Zeller', u'C', 'CHO')
# 302 (u'Trevor', u'Ariza', u'Trevor Ariza', u'SF', 'HOU')
# 303 (u'Michael', u'Beasley', u'Michael Beasley', u'PF', 'HOU')
# 304 (u'Patrick', u'Beverley', u'Patrick Beverley', u'PG', 'HOU')
# 305 (u'Corey', u'Brewer', u'Corey Brewer', u'SF', 'HOU')
# 306 (u'Clint', u'Capela', u'Clint Capela', u'C', 'HOU')
# 307 (u'Sam', u'Dekker', u'Sam Dekker', u'PF', 'HOU')
# 308 (u'Andrew', u'Goudelock', u'Andrew Goudelock', u'PG', 'HOU')
# 309 (u'James', u'Harden', u'James Harden', u'SG', 'HOU')
# 310 (u'Montrezl', u'Harrell', u'Montrezl Harrell', u'PF', 'HOU')
# 311 (u'Chuck', u'Hayes', u'Chuck Hayes', u'C', 'HOU')
# 312 (u'Dwight', u'Howard', u'Dwight Howard', u'C', 'HOU')
# 313 (u'Terrence', u'Jones', u'Terrence Jones', u'PF', 'HOU')
# 314 (u'Ty', u'Lawson', u'Ty Lawson', u'PG', 'HOU')
# 315 (u'K.J.', u'McDaniels', u'K.J. McDaniels', u'SF', 'HOU')
# 316 (u'Donatas', u'Motiejunas', u'Donatas Motiejunas', u'PF', 'HOU')
# 317 (u'Josh', u'Smith', u'Josh Smith', u'PF', 'HOU')
# 318 (u'Jason', u'Terry', u'Jason Terry', u'SG', 'HOU')
# 319 (u'Marcus', u'Thornton', u'Marcus Thornton', u'SG', 'HOU')
# 320 (u'Alan', u'Anderson', u'Alan Anderson', u'SG', 'WAS')
# 321 (u'Bradley', u'Beal', u'Bradley Beal', u'SG', 'WAS')
# 322 (u'DeJuan', u'Blair', u'DeJuan Blair', u'C', 'WAS')
# 323 (u'Jared', u'Dudley', u'Jared Dudley', u'PF', 'WAS')
# 324 (u'Jarell', u'Eddie', u'Jarell Eddie', u'SF', 'WAS')
# 325 (u'Drew', u'Gooden', u'Drew Gooden', u'PF', 'WAS')
# 326 (u'Marcin', u'Gortat', u'Marcin Gortat', u'C', 'WAS')
# 327 (u'J.J.', u'Hickson', u'J.J. Hickson', u'C', 'WAS')
# 328 (u'Nene', u'Hilario', u'Nene Hilario', u'PF', 'WAS')
# 329 (u'Ryan', u'Hollins', u'Ryan Hollins', u'C', 'WAS')
# 330 (u'Kris', u'Humphries', u'Kris Humphries', u'PF', 'WAS')
# 331 (u'Markieff', u'Morris', u'Markieff Morris', u'PF', 'WAS')
# 332 (u'Gary', u'Neal', u'Gary Neal', u'SG', 'WAS')
# 333 (u'Kelly', u'Oubre', u'Kelly Oubre', u'SF', 'WAS')
# 334 (u'Otto', u'Porter', u'Otto Porter', u'SF', 'WAS')
# 335 (u'Ramon', u'Sessions', u'Ramon Sessions', u'PG', 'WAS')
# 336 (u'Garrett', u'Temple', u'Garrett Temple', u'SF', 'WAS')
# 337 (u'Marcus', u'Thornton', u'Marcus Thornton', u'SG', 'WAS')
# 338 (u'John', u'Wall', u'John Wall', u'PG', 'WAS')
# 339 (u'Brandon', u'Bass', u'Brandon Bass', u'PF', 'LAL')
# 340 (u'Tarik', u'Black', u'Tarik Black', u'C', 'LAL')
# 341 (u'Anthony', u'Brown', u'Anthony Brown', u'SF', 'LAL')
# 342 (u'Kobe', u'Bryant', u'Kobe Bryant', u'SF', 'LAL')
# 343 (u'Jordan', u'Clarkson', u'Jordan Clarkson', u'SG', 'LAL')
# 344 (u'Roy', u'Hibbert', u'Roy Hibbert', u'C', 'LAL')
# 345 (u'Marcelo', u'Huertas', u'Marcelo Huertas', u'PG', 'LAL')
# 346 (u'Ryan', u'Kelly', u'Ryan Kelly', u'PF', 'LAL')
# 347 (u'Larry', u'Nance', u'Larry Nance', u'PF', 'LAL')
# 348 (u'Julius', u'Randle', u'Julius Randle', u'PF', 'LAL')
# 349 (u"D'Angelo", u'Russell', u"D'Angelo Russell", u'PG', 'LAL')
# 350 (u'Robert', u'Sacre', u'Robert Sacre', u'C', 'LAL')
# 351 (u'Lou', u'Williams', u'Lou Williams', u'SG', 'LAL')
# 352 (u'Metta', u'World Peace', u'Metta World Peace', u'SF', 'LAL')
# 353 (u'Nick', u'Young', u'Nick Young', u'SG', 'LAL')
# 354 (u'Elton', u'Brand', u'Elton Brand', u'C', 'PHI')
# 355 (u'Isaiah', u'Canaan', u'Isaiah Canaan', u'SG', 'PHI')
# 356 (u'Robert', u'Covington', u'Robert Covington', u'SF', 'PHI')
# 357 (u'Jerami', u'Grant', u'Jerami Grant', u'PF', 'PHI')
# 358 (u'Richaun', u'Holmes', u'Richaun Holmes', u'PF', 'PHI')
# 359 (u'Carl', u'Landry', u'Carl Landry', u'PF', 'PHI')
# 360 (u'Kendall', u'Marshall', u'Kendall Marshall', u'PG', 'PHI')
# 361 (u'T.J.', u'McConnell', u'T.J. McConnell', u'PG', 'PHI')
# 362 (u'Nerlens', u'Noel', u'Nerlens Noel', u'C', 'PHI')
# 363 (u'Jahlil', u'Okafor', u'Jahlil Okafor', u'C', 'PHI')
# 364 (u'Phil', u'Pressey', u'Phil Pressey', u'PG', 'PHI')
# 365 (u'JaKarr', u'Sampson', u'JaKarr Sampson', u'SF', 'PHI')
# 366 (u'Ish', u'Smith', u'Ish Smith', u'PG', 'PHI')
# 367 (u'Nik', u'Stauskas', u'Nik Stauskas', u'SG', 'PHI')
# 368 (u'Hollis', u'Thompson', u'Hollis Thompson', u'SG', 'PHI')
# 369 (u'Sonny', u'Weems', u'Sonny Weems', u'SF', 'PHI')
# 370 (u'Christian', u'Wood', u'Christian Wood', u'PF', 'PHI')
# 371 (u'Tony', u'Wroten', u'Tony Wroten', u'PG', 'PHI')
# 372 (u'Eric', u'Bledsoe', u'Eric Bledsoe', u'PG', 'PHO')
# 373 (u'Devin', u'Booker', u'Devin Booker', u'SG', 'PHO')
# 374 (u'Lorenzo', u'Brown', u'Lorenzo Brown', u'PG', 'PHO')
# 375 (u'Chase', u'Budinger', u'Chase Budinger', u'SF', 'PHO')
# 376 (u'Tyson', u'Chandler', u'Tyson Chandler', u'C', 'PHO')
# 377 (u'Bryce', u'Cotton', u'Bryce Cotton', u'PG', 'PHO')
# 378 (u'Archie', u'Goodwin', u'Archie Goodwin', u'PG', 'PHO')
# 379 (u'Kris', u'Humphries', u'Kris Humphries', u'PF', 'PHO')
# 380 (u'Cory', u'Jefferson', u'Cory Jefferson', u'PF', 'PHO')
# 381 (u'John', u'Jenkins', u'John Jenkins', u'SG', 'PHO')
# 382 (u'Orlando', u'Johnson', u'Orlando Johnson', u'SG', 'PHO')
# 383 (u'Brandon', u'Knight', u'Brandon Knight', u'SG', 'PHO')
# 384 (u'Alex', u'Len', u'Alex Len', u'C', 'PHO')
# 385 (u'Jon', u'Leuer', u'Jon Leuer', u'PF', 'PHO')
# 386 (u'Jordan', u'McRae', u'Jordan McRae', u'PG', 'PHO')
# 387 (u'Markieff', u'Morris', u'Markieff Morris', u'PF', 'PHO')
# 388 (u'Phil', u'Pressey', u'Phil Pressey', u'PG', 'PHO')
# 389 (u'Ronnie', u'Price', u'Ronnie Price', u'PG', 'PHO')
# 390 (u'Mirza', u'Teletovic', u'Mirza Teletovic', u'PF', 'PHO')
# 391 (u'P.J.', u'Tucker', u'P.J. Tucker', u'SF', 'PHO')
# 392 (u'T.J.', u'Warren', u'T.J. Warren', u'SF', 'PHO')
# 393 (u'Sonny', u'Weems', u'Sonny Weems', u'SG', 'PHO')
# 394 (u'Alan', u'Williams', u'Alan Williams', u'PF', 'PHO')
# 395 (u'Jordan', u'Adams', u'Jordan Adams', u'SG', 'MEM')
# 396 (u'Tony', u'Allen', u'Tony Allen', u'SG', 'MEM')
# 397 (u'Chris', u'Andersen', u'Chris Andersen', u'C', 'MEM')
# 398 (u'Matt', u'Barnes', u'Matt Barnes', u'SF', 'MEM')
# 399 (u'Vince', u'Carter', u'Vince Carter', u'SG', 'MEM')
# 400 (u'Mario', u'Chalmers', u'Mario Chalmers', u'PG', 'MEM')
# 401 (u'Mike', u'Conley', u'Mike Conley', u'PG', 'MEM')
# 402 (u'Bryce', u'Cotton', u'Bryce Cotton', u'PG', 'MEM')
# 403 (u'James', u'Ennis', u'James Ennis', u'SF', 'MEM')
# 404 (u'Jordan', u'Farmar', u'Jordan Farmar', u'PG', 'MEM')
# 405 (u'Marc', u'Gasol', u'Marc Gasol', u'C', 'MEM')
# 406 (u'JaMychal', u'Green', u'JaMychal Green', u'PF', 'MEM')
# 407 (u'Jeff', u'Green', u'Jeff Green', u'SF', 'MEM')
# 408 (u'P.J.', u'Hairston', u'P.J. Hairston', u'SF', 'MEM')
# 409 (u'Ryan', u'Hollins', u'Ryan Hollins', u'C', 'MEM')
# 410 (u'Courtney', u'Lee', u'Courtney Lee', u'SG', 'MEM')
# 411 (u'Jarell', u'Martin', u'Jarell Martin', u'PF', 'MEM')
# 412 (u'Ray', u'McCallum', u'Ray McCallum', u'PG', 'MEM')
# 413 (u'Xavier', u'Munford', u'Xavier Munford', u'SG', 'MEM')
# 414 (u'Zach', u'Randolph', u'Zach Randolph', u'PF', 'MEM')
# 415 (u'Russ', u'Smith', u'Russ Smith', u'PG', 'MEM')
# 416 (u'Lance', u'Stephenson', u'Lance Stephenson', u'SF', 'MEM')
# 417 (u'Alex', u'Stepheson', u'Alex Stepheson', u'PF', 'MEM')
# 418 (u'Jarnell', u'Stokes', u'Jarnell Stokes', u'C', 'MEM')
# 419 (u'Beno', u'Udrih', u'Beno Udrih', u'PG', 'MEM')
# 420 (u'Briante', u'Weber', u'Briante Weber', u'PG', 'MEM')
# 421 (u'Elliot', u'Williams', u'Elliot Williams', u'PG', 'MEM')
# 422 (u'Brandan', u'Wright', u'Brandan Wright', u'PF', 'MEM')
# 423 (u'Cole', u'Aldrich', u'Cole Aldrich', u'C', 'LAC')
# 424 (u'Jeff', u'Ayres', u'Jeff Ayres', u'C', 'LAC')
# 425 (u'Jamal', u'Crawford', u'Jamal Crawford', u'SG', 'LAC')
# 426 (u'Branden', u'Dawson', u'Branden Dawson', u'PF', 'LAC')
# 427 (u'Jeff', u'Green', u'Jeff Green', u'SF', 'LAC')
# 428 (u'Blake', u'Griffin', u'Blake Griffin', u'PF', 'LAC')
# 429 (u'Wesley', u'Johnson', u'Wesley Johnson', u'SF', 'LAC')
# 430 (u'DeAndre', u'Jordan', u'DeAndre Jordan', u'C', 'LAC')
# 431 (u'Luc', u'Mbah a Moute', u'Luc Mbah a Moute', u'PF', 'LAC')
# 432 (u'Chris', u'Paul', u'Chris Paul', u'PG', 'LAC')
# 433 (u'Paul', u'Pierce', u'Paul Pierce', u'SF', 'LAC')
# 434 (u'Pablo', u'Prigioni', u'Pablo Prigioni', u'PG', 'LAC')
# 435 (u'J.J.', u'Redick', u'J.J. Redick', u'SG', 'LAC')
# 436 (u'Austin', u'Rivers', u'Austin Rivers', u'SG', 'LAC')
# 437 (u'Josh', u'Smith', u'Josh Smith', u'PF', 'LAC')
# 438 (u'Lance', u'Stephenson', u'Lance Stephenson', u'SF', 'LAC')
# 439 (u'Alex', u'Stepheson', u'Alex Stepheson', u'PF', 'LAC')
# 440 (u'C.J.', u'Wilcox', u'C.J. Wilcox', u'SG', 'LAC')
# 441 (u'Justin', u'Anderson', u'Justin Anderson', u'SF', 'DAL')
# 442 (u'J.J.', u'Barea', u'J.J. Barea', u'PG', 'DAL')
# 443 (u'Jeremy', u'Evans', u'Jeremy Evans', u'SF', 'DAL')
# 444 (u'Raymond', u'Felton', u'Raymond Felton', u'PG', 'DAL')
# 445 (u'Devin', u'Harris', u'Devin Harris', u'PG', 'DAL')
# 446 (u'John', u'Jenkins', u'John Jenkins', u'SG', 'DAL')
# 447 (u'David', u'Lee', u'David Lee', u'PF', 'DAL')
# 448 (u'Wesley', u'Matthews', u'Wesley Matthews', u'SF', 'DAL')
# 449 (u'JaVale', u'McGee', u'JaVale McGee', u'C', 'DAL')
# 450 (u'Salah', u'Mejri', u'Salah Mejri', u'C', 'DAL')
# 451 (u'Dirk', u'Nowitzki', u'Dirk Nowitzki', u'PF', 'DAL')
# 452 (u'Zaza', u'Pachulia', u'Zaza Pachulia', u'C', 'DAL')
# 453 (u'Chandler', u'Parsons', u'Chandler Parsons', u'SF', 'DAL')
# 454 (u'Dwight', u'Powell', u'Dwight Powell', u'PF', 'DAL')
# 455 (u'Charlie', u'Villanueva', u'Charlie Villanueva', u'PF', 'DAL')
# 456 (u'Deron', u'Williams', u'Deron Williams', u'PG', 'DAL')
# 457 (u'Keith', u'Appling', u'Keith Appling', u'PG', 'ORL')
# 458 (u'Dewayne', u'Dedmon', u'Dewayne Dedmon', u'C', 'ORL')
# 459 (u'Evan', u'Fournier', u'Evan Fournier', u'SF', 'ORL')
# 460 (u'Channing', u'Frye', u'Channing Frye', u'PF', 'ORL')
# 461 (u'Aaron', u'Gordon', u'Aaron Gordon', u'PF', 'ORL')
# 462 (u'Tobias', u'Harris', u'Tobias Harris', u'PF', 'ORL')
# 463 (u'Mario', u'Hezonja', u'Mario Hezonja', u'SF', 'ORL')
# 464 (u'Ersan', u'Ilyasova', u'Ersan Ilyasova', u'PF', 'ORL')
# 465 (u'Brandon', u'Jennings', u'Brandon Jennings', u'PG', 'ORL')
# 466 (u'Devyn', u'Marble', u'Devyn Marble', u'SG', 'ORL')
# 467 (u'Shabazz', u'Napier', u'Shabazz Napier', u'PG', 'ORL')
# 468 (u'Andrew', u'Nicholson', u'Andrew Nicholson', u'PF', 'ORL')
# 469 (u'Victor', u'Oladipo', u'Victor Oladipo', u'SG', 'ORL')
# 470 (u'Elfrid', u'Payton', u'Elfrid Payton', u'PG', 'ORL')
# 471 (u'Jason', u'Smith', u'Jason Smith', u'C', 'ORL')
# 472 (u'Nikola', u'Vucevic', u'Nikola Vucevic', u'C', 'ORL')
# 473 (u'C.J.', u'Watson', u'C.J. Watson', u'PG', 'ORL')
# 474 (u'Andrea', u'Bargnani', u'Andrea Bargnani', u'C', 'BRK')
# 475 (u'Bojan', u'Bogdanovic', u'Bojan Bogdanovic', u'SF', 'BRK')
# 476 (u'Markel', u'Brown', u'Markel Brown', u'SG', 'BRK')
# 477 (u'Wayne', u'Ellington', u'Wayne Ellington', u'SG', 'BRK')
# 478 (u'Rondae', u'Hollis-Jefferson', u'Rondae Hollis-Jefferson', u'SF', 'BRK')
# 479 (u'Jarrett', u'Jack', u'Jarrett Jack', u'PG', 'BRK')
# 480 (u'Joe', u'Johnson', u'Joe Johnson', u'SF', 'BRK')
# 481 (u'Sergey', u'Karasev', u'Sergey Karasev', u'SF', 'BRK')
# 482 (u'Sean', u'Kilpatrick', u'Sean Kilpatrick', u'SG', 'BRK')
# 483 (u'Shane', u'Larkin', u'Shane Larkin', u'PG', 'BRK')
# 484 (u'Brook', u'Lopez', u'Brook Lopez', u'C', 'BRK')
# 485 (u'Chris', u'McCullough', u'Chris McCullough', u'PF', 'BRK')
# 486 (u'Willie', u'Reed', u'Willie Reed', u'C', 'BRK')
# 487 (u'Thomas', u'Robinson', u'Thomas Robinson', u'PF', 'BRK')
# 488 (u'Henry', u'Sims', u'Henry Sims', u'C', 'BRK')
# 489 (u'Donald', u'Sloan', u'Donald Sloan', u'PG', 'BRK')
# 490 (u'Thaddeus', u'Young', u'Thaddeus Young', u'PF', 'BRK')
# 491 (u'Lavoy', u'Allen', u'Lavoy Allen', u'PF', 'IND')
# 492 (u'Chase', u'Budinger', u'Chase Budinger', u'SF', 'IND')
# 493 (u'Rakeem', u'Christmas', u'Rakeem Christmas', u'PF', 'IND')
# 494 (u'Monta', u'Ellis', u'Monta Ellis', u'SG', 'IND')
# 495 (u'Paul', u'George', u'Paul George', u'SF', 'IND')
# 496 (u'George', u'Hill', u'George Hill', u'PG', 'IND')
# 497 (u'Jordan', u'Hill', u'Jordan Hill', u'C', 'IND')
# 498 (u'Solomon', u'Hill', u'Solomon Hill', u'SF', 'IND')
# 499 (u'Ty', u'Lawson', u'Ty Lawson', u'PG', 'IND')
# 500 (u'Ian', u'Mahinmi', u'Ian Mahinmi', u'C', 'IND')
# 501 (u'C.J.', u'Miles', u'C.J. Miles', u'SF', 'IND')
# 502 (u'Glenn', u'Robinson', u'Glenn Robinson', u'SF', 'IND')
# 503 (u'Rodney', u'Stuckey', u'Rodney Stuckey', u'PG', 'IND')
# 504 (u'Myles', u'Turner', u'Myles Turner', u'C', 'IND')
# 505 (u'Shayne', u'Whittington', u'Shayne Whittington', u'PF', 'IND')
# 506 (u'Joe', u'Young', u'Joe Young', u'PG', 'IND')
# 507 (u'Alexis', u'Ajinca', u'Alexis Ajinca', u'C', 'NOP')
# 508 (u'Ryan', u'Anderson', u'Ryan Anderson', u'PF', 'NOP')
# 509 (u'Omer', u'Asik', u'Omer Asik', u'C', 'NOP')
# 510 (u'Luke', u'Babbitt', u'Luke Babbitt', u'SF', 'NOP')
# 511 (u'Norris', u'Cole', u'Norris Cole', u'PG', 'NOP')
# 512 (u'Dante', u'Cunningham', u'Dante Cunningham', u'SF', 'NOP')
# 513 (u'Anthony', u'Davis', u'Anthony Davis', u'C', 'NOP')
# 514 (u'Bryce', u'Dejean-Jones', u'Bryce Dejean-Jones', u'SG', 'NOP')
# 515 (u'Toney', u'Douglas', u'Toney Douglas', u'PG', 'NOP')
# 516 (u'James', u'Ennis', u'James Ennis', u'SF', 'NOP')
# 517 (u'Tyreke', u'Evans', u'Tyreke Evans', u'SG', 'NOP')
# 518 (u'Tim', u'Frazier', u'Tim Frazier', u'PG', 'NOP')
# 519 (u'Jimmer', u'Fredette', u'Jimmer Fredette', u'SG', 'NOP')
# 520 (u'Alonzo', u'Gee', u'Alonzo Gee', u'SF', 'NOP')
# 521 (u'Eric', u'Gordon', u'Eric Gordon', u'SG', 'NOP')
# 522 (u'Jordan', u'Hamilton', u'Jordan Hamilton', u'SF', 'NOP')
# 523 (u'Jrue', u'Holiday', u'Jrue Holiday', u'PG', 'NOP')
# 524 (u'Orlando', u'Johnson', u'Orlando Johnson', u'SG', 'NOP')
# 525 (u'Kendrick', u'Perkins', u'Kendrick Perkins', u'C', 'NOP')
# 526 (u'Nate', u'Robinson', u'Nate Robinson', u'PG', 'NOP')
# 527 (u'Ish', u'Smith', u'Ish Smith', u'PG', 'NOP')

# %%
NBA_dataset = pd.read_csv("NBA_teamnamepos_data.csv", sep=",")
NBA_dataset.head()
# Out:
#    Unnamed: 0 first_name        last_name                    names pos team
# 0           0    Giannis    Antetokounmpo    Giannis Antetokounmpo  PG  MIL
# 1           1     Jerryd          Bayless           Jerryd Bayless  SG  MIL
# 2           2    Michael  Carter-Williams  Michael Carter-Williams  PG  MIL
# 3           3      Chris         Copeland           Chris Copeland  PF  MIL
# 4           4      Jared       Cunningham         Jared Cunningham  SG  MIL
